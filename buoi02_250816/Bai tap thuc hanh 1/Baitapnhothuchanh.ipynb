# %% [markdown]
# ### Bài 1. In nhãn

# %%
# %run "InNhan.py"
# Out:
# ***************************
# * Truong: Dai Hoc UEH     *
# * Khoa: CNTT              *
# * Ho ten:                 *
# ***************************

# %% [markdown]
# ### Bài 2. Tính diện tích và chu hình tròn

# %%
# %run "HinhTron.py"
# Out:
# Nhap ban kinh R:  5
# Dien tich S = 78.5
# Chu vi P = 31.4

# %% [markdown]
# ### Bài 3. Đổi sang giây

# %%
# %run "DoiSangGiay.py"
# Out:
# Nhap so gio:  1
# Nhap so phut:  20
# Nhap so giay:  10
# Tong so giay cua 1:20:10 la 4810 giay

# %% [markdown]
# ### Bài 4. Đổi sang giờ phút giây

# %%
# %run "DoiSangGioPhutGiay.py"
# Out:
# Nhap vao tong so giay:  4810
# 4810 giay co dang 1:20:10

# %% [markdown]
# ### Bài 5. Tính diện tích tam giác

# %%
# %run "DienTichTamGiac.py"
# Out:
# Nhap do dai canh a:  2
# Nhap do dai canh b:  4
# Nhap do dai canh c:  3
# Dien tich tam giac S = 2.90

# %% [markdown]
# ### Bài 6. Hàm Mũ

# %%
# %run "TinhMu.py"
# Out:
# Nhap so thuc a:  2
# Nhap so mu n:  4
# Ket qua 2.0^4 = 16.0

# %% [markdown]
# ### Bài 7. Đảo số

# %%
# %run "DaoSo.py"
# Out:
# Nhap so nguyen co 4 chu so:  1234
# So dao cua 1234 la 4321

# %% [markdown]
# ### Bài 8. Độ sang Radian

# %%
# %run "DoSangRadian.py"
# Out:
# Nhap goc (do):  25
# 25.0 do = 0.4363 radian

# %% [markdown]
# ### Bài 9. Hàm số 1

# %%
# %run "HamSo1.py"
# Out:
# Nhap so thuc x:  4
# y1 = 196.00
# y2 = 0.00

# %% [markdown]
# ### Bài 10. Khoảng cách

# %%
# %run "KhoangCach.py"
# Out:
# Nhap hoanh do x1:  2
# Nhap tung do y1:  4
# Nhap hoanh do x2:  3
# Nhap tung do y2:  1
# Khoang cach giua A(2.0,4.0) va B(3.0,1.0) la 3.16

# %%
# !jupyter nbconvert Baitapnhothuchanh.ipynb --to html
# Out:
# [NbConvertApp] Converting notebook Baitapnhothuchanh.ipynb to html
# [NbConvertApp] Writing 296336 bytes to Baitapnhothuchanh.html
