# %%
# %%writefile SoSanh.in1
# 5
# 6
# Out:
# Overwriting SoSanh.in1

# %%
# !python SoSanh.py < SoSanh.in1
# Out:
# Moi ban nhap so a: Moi ban nhap so b: Cac ket qua tinh toan:
# 5     +     6 =    11
# 5     -     6 =    -1
# 5     *     6 =    30
# 5     /     6 =     0
# 5     /     6 =     5
# 5     /     6 =  0.83

# %%
! jupyter nbconvert bai02.ipynb --to html
# Out:
# [NbConvertApp] Converting notebook bai02.ipynb to html
# [NbConvertApp] Writing 271841 bytes to bai02.html
